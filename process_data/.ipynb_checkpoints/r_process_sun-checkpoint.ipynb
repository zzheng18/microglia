# %%
library(Seurat)
library(SeuratDisk)
# Out:
# Attaching SeuratObject
#
# Attaching sp
#
# Registered S3 method overwritten by 'SeuratDisk':
#   method            from
#   as.sparse.H5Group Seurat

# %%
rna = readRDS('/home/icb/zihe.zheng/projects/microglia/data/SUN/ROSMAP.ImmuneCells.6regions.snRNAseq.counts.rds')

# %%
meta = readRDS('/home/icb/zihe.zheng/projects/microglia/data/SUN/ROSMAP.ImmuneCells.6regions.snRNAseq.meta.rds')

# %%
atac = readRDS('/home/icb/zihe.zheng/projects/microglia/data/SUN/microglia.snATAC.ArchRobj.rds')

# %%
seurat_object <- CreateSeuratObject(rna, project = "SeuratProject", assay = "RNA", meta.data = meta)

# %%
seurat_object[["RNA"]] <- as(object = seurat_object[["RNA"]], Class = "Assay")

# %%
SaveH5Seurat(seurat_object, filename = "/home/icb/zihe.zheng/projects/microglia/data/SUN/MIT_ROSMAP_RNA.h5Seurat")
# Out:
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding counts for RNA
#
# Adding data for RNA
#
# No variable features found for RNA
#
# No feature-level metadata found for RNA

# %%
seurat_object_s <- LoadH5Seurat("/home/icb/zihe.zheng/projects/microglia/data/SUN/MIT_ROSMAP_RNA.h5Seurat")
# Out:
# Validating h5Seurat file
#
# Initializing RNA with data
#
# Adding counts for RNA
#
# Adding miscellaneous information for RNA
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results

# %%
Convert("/home/icb/zihe.zheng/projects/microglia/data/SUN/MIT_ROSMAP_RNA.h5Seurat", dest = "h5ad")
# Out:
# Validating h5Seurat file
#
# Adding data from RNA as X
#
# Adding counts from RNA as raw
#
# Transfering meta.data to obs

# %%
if (!requireNamespace("BiocManager", quietly = TRUE)) install.packages("BiocManager")

# %%
if (!requireNamespace("devtools", quietly = TRUE)) install.packages("devtools")

# %% [markdown]
# ## read atac-seq data

# %%
Sys.setenv(CONDA_BUILD_SYSROOT="/")

# %%
options(buildtools.check = function(action) TRUE )

# %%
devtools::install_github("GreenleafLab/ArchR", ref="master", repos = BiocManager::repositories())
# Out:
# Using github PAT from envvar GITHUB_PAT
#
# ...
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
# crayon       (1.5.1      -> 1.5.3    ) [CRAN]
# GlobalOpt... (NA         -> 0.1.2    ) [CRAN]
# colorspace   (2.0-3      -> 2.1-1    ) [CRAN]
# shape        (NA         -> 1.4.6.1  ) [CRAN]
# zlibbioc     (1.34.0     -> 1.36.0   ) [CRAN]
# IRanges      (2.22.1     -> 2.24.1   ) [CRAN]
# S4Vectors    (0.26.0     -> 0.28.1   ) [CRAN]
# BiocGenerics (0.34.0     -> 0.36.1   ) [CRAN]
# BH           (1.78.0-0   -> 1.84.0-0 ) [CRAN]
# Rcpp         (1.0.9      -> 1.0.13   ) [CRAN]
# RcppEigen    (0.3.3.9.2  -> 0.3.4.0.2) [CRAN]
# fs           (1.5.2      -> 1.6.4    ) [CRAN]
# glue         (1.6.2      -> 1.7.0    ) [CRAN]
# cli          (3.4.1      -> 3.6.3    ) [CRAN]
# sass         (0.4.2      -> 0.4.9    ) [CRAN]
# ...

# %%
library(ArchR)
# Out:
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
# ...

# %%
atac = readRDS('/home/icb/zihe.zheng/projects/microglia/data/SUN/microglia.snATAC.ArchRobj.rds')

# %%
atac
# Out:
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /net/bmc-lab5/data/kellis/users/nasun/projects/project0.microglia/analysis.snATAC/1archr.luria.Mar2022/brain.microglia.filter
# samples(293): D19-122585 D19-122586 ... D19-8636 D19-8637
# sampleColData names(1): ArrowFiles
# cellColData names(19): subject Sample ... pmi cellstate
# numberOfCells(1): 41832
# medianTSS(1): 9.4885
# medianFrags(1): 4755.5

# %%
saveArchRProject(ArchRProj = atac, outputDirectory = "/home/icb/zihe.zheng/projects/microglia/data/SUN/arrows/", load = FALSE)
# Out:
# Warning message in normalizePath(getOutputDirectory(ArchRProj)):
# “path[1]="/net/bmc-lab5/data/kellis/users/nasun/projects/project0.microglia/analysis.snATAC/1archr.luria.Mar2022/brain.microglia.filter": No such file or directory”
# Copying ArchRProject to new outputDirectory : /ictstr01/home/icb/zihe.zheng/projects/microglia/data/SUN/arrows
#
# Copying Arrow Files...
#
# Copying Arrow Files (1 of 293)
#
# Copying Arrow Files (2 of 293)
#
# Copying Arrow Files (3 of 293)
#
# Copying Arrow Files (4 of 293)
#
# Copying Arrow Files (5 of 293)
#
# Copying Arrow Files (6 of 293)
#
# Copying Arrow Files (7 of 293)
#
# Copying Arrow Files (8 of 293)
#
# Copying Arrow Files (9 of 293)
#
# Copying Arrow Files (10 of 293)
#
# Copying Arrow Files (11 of 293)
#
# Copying Arrow Files (12 of 293)
#
# Copying Arrow Files (13 of 293)
#
# Copying Arrow Files (14 of 293)
#
# Copying Arrow Files (15 of 293)
#
# Copying Arrow Files (16 of 293)
#
# Copying Arrow Files (17 of 293)
#
# ...

# %%
loadArchRProject(path = "/home/icb/zihe.zheng/projects/microglia/data/SUN/microglia.snATAC.ArchRobj.rds", force = FALSE, showLogo = FALSE)

# %%
atac.ArrowFiles
# Out:
# Error in eval(expr, envir, enclos): object 'atac.ArrowFiles' not found
# Traceback:

# %%
getAvailableMatrices(atac)
# Out:
# Error in h5checktypeOrOpenLoc(file, readonly = TRUE, fapl = NULL, native = native): Error in h5checktypeOrOpenLoc(). Cannot open file. File 'D19-122585.arrow' does not exist.
# Traceback:
#
# 1. getAvailableMatrices(atac)
# 2. .availableArrays(getArrowFiles(ArchRProj = ArchRProj))
# 3. .safelapply(seq_along(ArrowFiles), function(x) {
#  .     groups <- h5ls(ArrowFiles[x]) %>% {
#  .         .[.$group == "/" & .$otype == "H5I_GROUP", "name"]
#  .     }
#  .     groups <- groups[!grepl("Fragments|Metadata", groups)]
#  .     groups
#  . }, threads = threads) %>% Reduce("intersect", .)
# 4. Reduce("intersect", .)
# 5. .safelapply(seq_along(ArrowFiles), function(x) {
#  .     groups <- h5ls(ArrowFiles[x]) %>% {
#  .         .[.$group == "/" & .$otype == "H5I_GROUP", "name"]
#  .     }
#  .     groups <- groups[!grepl("Fragments|Metadata", groups)]
#  .     groups
#  . }, threads = threads)
# 6. lapply(...)
# 7. FUN(X[[i]], ...)
# 8. h5ls(ArrowFiles[x]) %>% {
# ...

# %%
proj <- filterDoublets(ArchRProj = atac)
# Out:
# Error in value[[3L]](cond): select Not Found in Colnames of cellColData:
# Error in `dplyr::mutate()`:
# ℹ In argument: `tmpNewCol123 = eval(parse(text = select[x]))`.
# Caused by error:
# ! object 'DoubletEnrichment' not found
#
# Traceback:
#
# 1. filterDoublets(ArchRProj = atac)
# 2. getCellColData(ArchRProj, c("Sample", "DoubletEnrichment", "DoubletScore"))
# 3. lapply(seq_along(select), function(x) {
#  .     tryCatch({
#  .         data.frame(dplyr::mutate(ccd, tmpNewCol123 = eval(parse(text = select[x])))[,
#  .             "tmpNewCol123"], stringsAsFactors = FALSE)
#  .     }, error = function(x) {
#  .         stop("select Not Found in Colnames of cellColData:\n",
#  .             x)
#  .     })
#  . }) %>% Reduce("cbind", .) %>% {
#  .     data.frame(., stringsAsFactors = FALSE)
#  . }
# 4. Reduce("cbind", .)
# 5. lapply(seq_along(select), function(x) {
#  .     tryCatch({
#  .         data.frame(dplyr::mutate(ccd, tmpNewCol123 = eval(parse(text = select[x])))[,
# ...

# %%
# there is no actual data in the rds file for atac-seq
