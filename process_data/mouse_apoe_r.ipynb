# %%
library(Seurat)
library(SeuratDisk)
# Out:
# Registered S3 method overwritten by 'SeuratDisk':
#   method            from
#   as.sparse.H5Group Seurat

# %%
rna = readRDS('/lustre/groups/ml01/projects/2024_microglia_zihe.zheng/mouse_apoe/GSE225503_adapoe.rds')

# %%
rna
# Out:
# An object of class Seurat
# 51933 features across 30868 samples within 4 assays
# Active assay: SCT (16645 features, 0 variable features)
#  3 other assays present: RNA, HTO, integrated
#  2 dimensional reductions calculated: pca, umap

# %%
DefaultAssay(rna) <- 'RNA'

# %%
DefaultAssay(rna)
# Out:
# [1] "RNA"

# %%
SaveH5Seurat(rna, filename = '/lustre/groups/ml01/projects/2024_microglia_zihe.zheng/mouse_apoe/GSE225503_adapoe.h5Seurat', assays = c("SCT", "RNA", "HTO", "integrated"), reductions = c("pca", "umap"), overwrite = TRUE)
# Out:
# Warning message:
# “Overwriting previous file /lustre/groups/ml01/projects/2024_microglia_zihe.zheng/mouse_apoe/GSE225503_adapoe.h5Seurat”
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding counts for RNA
#
# Adding data for RNA
#
# No variable features found for RNA
#
# No feature-level metadata found for RNA
#
# Adding counts for HTO
#
# Adding data for HTO
#
# No variable features found for HTO
#
# No feature-level metadata found for HTO
#
# Adding counts for SCT
#
# Adding data for SCT
#
# Adding scale.data for SCT
#
# No variable features found for SCT
#
# No feature-level metadata found for SCT
#
# Writing out SCTModel.list for SCT
#
# Adding data for integrated
#
# Adding scale.data for integrated
#
# Adding variable features for integrated
#
# No feature-level metadata found for integrated
#
# Writing out SCTModel.list for integrated
#
# Adding cell embeddings for pca
#
# Adding loadings for pca
#
# No projected loadings for pca
#
# Adding standard deviations for pca
# ...

# %%
Convert('/lustre/groups/ml01/projects/2024_microglia_zihe.zheng/mouse_apoe/GSE225503_adapoe.h5Seurat', dest = "h5ad", overwrite = TRUE)
# Out:
# Validating h5Seurat file
#
# Adding data from RNA as X
#
# Adding counts from RNA as raw
#
# Transfering meta.data to obs
#
# Adding dimensional reduction information for umap (global)

# %%
micro = readRDS('/lustre/groups/ml01/projects/2024_microglia_zihe.zheng/mouse_apoe/GSE225503_mglia_only.rds')

# %%
micro
# Out:
# Loading required package: SeuratObject
#
# Attaching sp
#
# Loading required package: Seurat
# An object of class Seurat
# 52423 features across 24750 samples within 4 assays
# Active assay: SCT (17135 features, 3000 variable features)
#  3 other assays present: RNA, HTO, integrated
#  2 dimensional reductions calculated: pca, umap

# %%
micro@meta.data
# Out:
#                            orig.ident nCount_RNA nFeature_RNA nCount_HTO
# E2_10wk_AAACCTGAGCTCCTCT-1 E2_10wk    3718       1819         468
# E2_10wk_AAACCTGAGTTACCCA-1 E2_10wk    2364       1370         444
# E2_10wk_AAACCTGCAATAAGCA-1 E2_10wk    3553       1876         342
# E2_10wk_AAACCTGCAGCCACCA-1 E2_10wk    3512       1816         384
# E2_10wk_AAACCTGCAGGGATTG-1 E2_10wk    6017       2521         887
# E2_10wk_AAACCTGCATGCAATC-1 E2_10wk    4538       2084         557
# E2_10wk_AAACCTGTCCTAAGTG-1 E2_10wk    2682       1563         400
# E2_10wk_AAACGGGAGGCCGAAT-1 E2_10wk    2678       1471         478
# E2_10wk_AAACGGGAGGTGCTAG-1 E2_10wk    3324       1767         379
# E2_10wk_AAACGGGCAGCTGTGC-1 E2_10wk    5167       2386         296
# E2_10wk_AAACGGGCAGGATCGA-1 E2_10wk     817        599         376
# E2_10wk_AAACGGGCATTATCTC-1 E2_10wk    2895       1530         463
# E2_10wk_AAACGGGGTAAATGTG-1 E2_10wk    3590       1933         367
# ...

# %%
write.csv(micro@meta.data, "/lustre/groups/ml01/projects/2024_microglia_zihe.zheng/mouse_apoe/microglia_cluster.csv")

# %%
DefaultAssay(micro) <- 'RNA'

# %%
SaveH5Seurat(micro, filename = '/lustre/groups/ml01/projects/2024_microglia_zihe.zheng/mouse_apoe/GSE225503_mglia_only.h5Seurat', assays = c("SCT", "RNA", "HTO", "integrated"), reductions = c("pca", "umap"), overwrite = TRUE)
# Out:
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding counts for RNA
#
# Adding data for RNA
#
# No variable features found for RNA
#
# No feature-level metadata found for RNA
#
# Adding counts for HTO
#
# Adding data for HTO
#
# No variable features found for HTO
#
# No feature-level metadata found for HTO
#
# Adding counts for SCT
#
# Adding data for SCT
#
# Adding scale.data for SCT
#
# Adding variable features for SCT
#
# No feature-level metadata found for SCT
#
# Writing out SCTModel.list for SCT
#
# Adding data for integrated
#
# Adding scale.data for integrated
#
# Adding variable features for integrated
#
# No feature-level metadata found for integrated
#
# Writing out SCTModel.list for integrated
#
# Adding cell embeddings for pca
#
# Adding loadings for pca
#
# No projected loadings for pca
#
# Adding standard deviations for pca
#
# No JackStraw data for pca
#
# Adding cell embeddings for umap
#
# No loadings for umap
#
# No projected loadings for umap
#
# ...

# %%
Convert('/lustre/groups/ml01/projects/2024_microglia_zihe.zheng/mouse_apoe/GSE225503_mglia_only.h5Seurat', dest = "h5ad", overwrite = TRUE)
# Out:
# Validating h5Seurat file
#
# Adding data from RNA as X
#
# Adding counts from RNA as raw
#
# Transfering meta.data to obs
#
# Adding dimensional reduction information for umap (global)
