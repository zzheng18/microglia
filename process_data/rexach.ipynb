# %%
import scanpy as sc
import anndata as ad

# %%
adata = sc.read_h5ad('/lustre/groups/ml01/projects/2024_microglia_zihe.zheng/rexach/rexach.h5ad')

# %% [markdown]
# ## explore

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 432555 × 29968
#     obs: 'organism_ontology_term_id', 'tissue_ontology_term_id', 'assay_ontology_term_id', 'disease_ontology_term_id', 'cell_type_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'development_stage_ontology_term_id', 'sex_ontology_term_id', 'donor_id', 'suspension_type', 'ct_subcluster', 'library_id', 'tissue_type', 'is_primary_data', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid'
#     var: 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'vst.variable', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type'
#     uns: 'citation', 'schema_reference', 'schema_version', 'title', 'cell_type_colors', 'disease_ontology_term_id_colors', 'disease_colors'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'

# %%
sc.pl.umap(adata, color = ['cell_type', 'disease'])

# %%
adata.obs
# Out:
#                      organism_ontology_term_id tissue_ontology_term_id  \
# AAACCTGAGAATGTGT-1              NCBITaxon:9606          UBERON:0002436
# AAACCTGCAATCGAAA-1              NCBITaxon:9606          UBERON:0002436
# AAACCTGCACCTGGTG-1              NCBITaxon:9606          UBERON:0002436
# AAACCTGGTAAATGAC-1              NCBITaxon:9606          UBERON:0002436
# AAACCTGGTCGTCTTC-1              NCBITaxon:9606          UBERON:0002436
# ...                                        ...                     ...
# TTTGGTTTCCGCATAA-119            NCBITaxon:9606          UBERON:0013535
# TTTGTCAAGCCCAATT-119            NCBITaxon:9606          UBERON:0013535
# TTTGTCAGTCCGAACC-119            NCBITaxon:9606          UBERON:0013535
# TTTGTCAGTTGACGTT-119            NCBITaxon:9606          UBERON:0013535
# TTTGTCATCCTCGCAT-119            NCBITaxon:9606          UBERON:0013535
#
#                      assay_ontology_term_id disease_ontology_term_id  \
# ...

# %%
adata.var
# Out:
#                  vst.mean  vst.variance  vst.variance.expected  \
# gene_ids
# ENSG00000243485  0.000066      0.000066               0.000068
# ENSG00000186092  0.000124      0.000127               0.000128
# ENSG00000238009  0.043070      0.048379               0.058816
# ENSG00000239906  0.000091      0.000091               0.000094
# ENSG00000236601  0.000011      0.000011               0.000011
# ...                   ...           ...                    ...
# ENSG00000278384  0.019236      0.021295               0.024860
# ENSG00000278633  0.000029      0.000029               0.000030
# ENSG00000276345  0.003829      0.004087               0.004412
# ENSG00000271254  0.024744      0.026684               0.032664
# ENSG00000268674  0.000008      0.000008               0.000008
#
#                  vst.variance.standardized  vst.variable  feature_is_filtered  \
# gene_ids
# ENSG00000243485                   0.972672         False                False
# ...

# %%
adata.write_h5ad('/lustre/groups/ml01/projects/2024_microglia_zihe.zheng/rexach/rexach.h5ad')

# %% [markdown]
# ## get microglia cells

# %%
adata.obs.cell_type
# Out:
# AAACCTGAGAATGTGT-1                glutamatergic neuron
# AAACCTGCAATCGAAA-1                           astrocyte
# AAACCTGCACCTGGTG-1                glutamatergic neuron
# AAACCTGGTAAATGAC-1                glutamatergic neuron
# AAACCTGGTCGTCTTC-1                glutamatergic neuron
#                                      ...
# TTTGGTTTCCGCATAA-119            inhibitory interneuron
# TTTGTCAAGCCCAATT-119            inhibitory interneuron
# TTTGTCAGTCCGAACC-119              glutamatergic neuron
# TTTGTCAGTTGACGTT-119    oligodendrocyte precursor cell
# TTTGTCATCCTCGCAT-119              glutamatergic neuron
# Name: cell_type, Length: 432555, dtype: category
# Categories (9, object): ['astrocyte', 'endothelial cell of vascular tree', 'glutamatergic neuron', 'inhibitory interneuron', ..., 'oligodendrocyte', 'oligodendrocyte precursor cell', 'pericyte', 'T cell']

# %%
adata[adata.obs.cell_type == 'microglial']
